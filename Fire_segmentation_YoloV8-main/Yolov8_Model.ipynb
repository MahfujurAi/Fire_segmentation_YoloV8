# %%
# !nvidia-smi
# Out:
# Mon Apr  3 18:31:06 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.6/490.6 KB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 KB 23.8 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
#!yolo predict model=yolov8n.pt source='/content/drive/MyDrive/project1/valid/images/132-img1_png.rf.f5061c43c9891037e4979509505e45a7.jpg'
# !yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 147MB/s]
# Ultralytics YOLOv8.0.59 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 73.0MB/s]
# image 1/1 /content/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 21.0ms
# Speed: 0.7ms preprocess, 21.0ms inference, 45.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
#!yolo predict model=/content/drive/MyDrive/Dip_Project/dip_200/best.pt source='https://ultralytics.com/images/bus.jpg'
# Out:
# 2023-04-03 19:55:50.351850: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-03 19:55:51.608699: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71721619 parameters, 0 gradients, 343.7 GFLOPs
#
# ...
# 100% 476k/476k [00:00<00:00, 11.8MB/s]
# image 1/1 /content/bus.jpg: 640x480 (no detections), 78.6ms
# Speed: 0.7ms preprocess, 78.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)

# %%
#yolo segment val model=yolov8n-seg.pt  # val official model
#!yolo segment val model=/content/drive/MyDrive/Dip_Project/dip_100/best.pt  # val custom model

# %%
#!yolo segment predict model=yolov8n-seg.pt source='https://ultralytics.com/images/bus.jpg'  # predict with official model
# !yolo segment predict save=True  model=/content/drive/MyDrive/Dip_Project/dip_200/best200_20.pt source=/content/drive/MyDrive/Dip_Project/Video/fire5.mp4  # predict with custom model
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (581/5578) /content/drive/MyDrive/Dip_Project/Video/fire5.mp4: 640x384 (no detections), 43.0ms
# video 1/1 (582/5578) /content/drive/MyDrive/Dip_Project/Video/fire5.mp4: 640x384 (no detections), 44.0ms
# video 1/1 (583/5578) /content/drive/MyDrive/Dip_Project/Video/fire5.mp4: 640x384 (no detections), 40.5ms
# video 1/1 (584/5578) /content/drive/MyDrive/Dip_Project/Video/fire5.mp4: 640x384 (no detections), 44.1ms
# video 1/1 (585/5578) /content/drive/MyDrive/Dip_Project/Video/fire5.mp4: 640x384 (no detections), 40.8ms
# video 1/1 (586/5578) /content/drive/MyDrive/Dip_Project/Video/fire5.mp4: 640x384 (no detections), 44.6ms
# video 1/1 (587/5578) /content/drive/MyDrive/Dip_Project/Video/fire5.mp4: 640x384 (no detections), 40.6ms
# video 1/1 (588/5578) /content/drive/MyDrive/Dip_Project/Video/fire5.mp4: 640x384 (no detections), 42.9ms
# ...

# %%
# !yolo task=segment mode=train model=/content/drive/MyDrive/Dip_Project/dip_200/best.pt data= /content/drive/MyDrive/fireData_yolo/data.yaml epochs=20 imgsz=640 batch=4
# Out:
# Ultralytics YOLOv8.0.61 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
